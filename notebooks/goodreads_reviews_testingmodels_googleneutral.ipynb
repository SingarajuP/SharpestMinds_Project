# %%
from bs4 import BeautifulSoup
import requests  
import numpy as np
import pandas as pd
from langdetect import detect
import re
import pickle
from string import punctuation 
import nltk
import nltk.data
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords

# %%
#importing libraries for models and nlp tasks
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

# %%
tfidf_vectorizer=pickle.load(open('../tfidfvectors/tfidf_vect_emogoneutral.pkl','rb'))

# %%
test_model_lr=pickle.load(open('../models/lr_mn_emogoneutral.pkl','rb'))
test_model_lr_cw=pickle.load(open('../models/lr_mn_emogoneutral_cw.pkl','rb'))

# %%
emotion = pd.read_csv('../labels_prediction/emotions_googleneutral.csv')

dic_emotions=emotion.to_dict('series')

print(dic_emotions['emotion'])
# Out:
# 0     sadness
# 1         joy
# 2        love
# 3       anger
# 4        fear
# 5    surprise
# 6     neutral
# Name: emotion, dtype: object

# %% [markdown]
# #### Webscraping goodreads website for getting reviews of a book
# ##### To get the link for the required book

# %%
data = {'q': "razor's edge"}
book_url = "https://www.goodreads.com/search"
req = requests.get(book_url, params=data)

book_soup = BeautifulSoup(req.text, 'html.parser')

titles=book_soup.find_all('a', class_ = 'bookTitle')
title=[]
link=[]
for bookname in titles:
    title.append(bookname.get_text())
    link.append(bookname['href'])

# %% [markdown]
# ##### From all the links first link is the most closest search

# %%
rev="http://goodreads.com"+link[0]
rev_url = requests.get(rev)
rev_soup=BeautifulSoup(rev_url.content, 'html.parser')

# %% [markdown]
# ##### Getting reviews from the web page of the book

# %%
rev_list=[]
for x in rev_soup.find_all("section", {"class": "ReviewText"}):
    rev_list.append(x.text)

# %%
df=pd.DataFrame(rev_list, columns=['reviews'])
df
# Out:
#                                               reviews
# 0   \nIn all big cities there are self-contained g...
# 1   Books like this, that I’ve read so long ago in...
# 2   (Book 570 From 1001 Books) - The Razor’s Edge ...
# 3   The best novel I've read since joining Goodrea...
# 4   ASPRO IL CAMMINO VERSO LA SALVEZZAIl primo fil...
# 5   Oh, Mr. Maugham, there are moments when I love...
# 6   In 1919 war hero Larry (Laurence) Darrell retu...
# 7   Tracing the intimate lives of representative B...
# 8   This has to be the most endearing and accessib...
# 9   A Timeless, stirring drama, scaling the height...
# 10  In Asian countries, the custom of “home leavin...
# 11  It took me a long time to read this book, this...
# 12  “Its a toss-up when you decide to leave the be...
# 13  دلم میخواد مثل لری تو یه خونه کوچیک زندگی کنم،...
# 14  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 15  I didn't love it as much as I expected. The pr...
# 16  "One of Maugham's three major novels ..." TIME...
# 17  I am considering starting a project to find ou...
# 18  Self-sacrifice, a most "overwhelming" human "p...
# 19  I love this book. I absolutely adore it.Larry ...
# 20  Back in the dark days of the mid-’80s, I read ...
# 21  کی می‌تونه لاری رو دوست نداشته باشه و حسرت سبک...
# 22  «Η κόψη του ξυραφιού», συνολικά, είναι μια βαθ...
# 23  داشتم فکر می کردم که شخصیت یک نفر چقدر باید تا...
# 24  110th book of 2021.Our guests the other day we...
# 25  1.5بسیار ناکافی و کاملا سطحینویسنده محترممون، ...
# 26  در کتاب لبه تیغ نویسنده آقای سامرست موام به جس...
# 27  Chatty, erudite, engrossing and thoroughly ent...
# 28  This is a perspicacious study of characters wh...
# 29  “'What’s the good of knowledge if you’re not g...

# %% [markdown]
# ##### From all the languages in the reviews, selecting the english language reviews

# %%
def detect_en(text):
    try:
        return detect(text) == 'en'
    except:
        return False

# %%
df = df[df['reviews'].apply(detect_en)]
df=df.reset_index()
df
# Out:
#     index                                            reviews
# 0       0  \nIn all big cities there are self-contained g...
# 1       1  Books like this, that I’ve read so long ago in...
# 2       3  The best novel I've read since joining Goodrea...
# 3       5  Oh, Mr. Maugham, there are moments when I love...
# 4       6  In 1919 war hero Larry (Laurence) Darrell retu...
# 5       7  Tracing the intimate lives of representative B...
# 6       8  This has to be the most endearing and accessib...
# 7       9  A Timeless, stirring drama, scaling the height...
# 8      10  In Asian countries, the custom of “home leavin...
# 9      11  It took me a long time to read this book, this...
# 10     12  “Its a toss-up when you decide to leave the be...
# 11     14  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 12     15  I didn't love it as much as I expected. The pr...
# 13     16  "One of Maugham's three major novels ..." TIME...
# 14     17  I am considering starting a project to find ou...
# 15     18  Self-sacrifice, a most "overwhelming" human "p...
# 16     19  I love this book. I absolutely adore it.Larry ...
# 17     20  Back in the dark days of the mid-’80s, I read ...
# 18     24  110th book of 2021.Our guests the other day we...
# 19     27  Chatty, erudite, engrossing and thoroughly ent...
# 20     28  This is a perspicacious study of characters wh...
# 21     29  “'What’s the good of knowledge if you’re not g...

# %%
#df.to_csv("razorsedge.csv",index=False,header=False)

# %% [markdown]
# ##### Cleaning the text

# %%
def text_cleaning(text):
   
    text=re.sub("\(.*?\)","",text)

    text = re.sub(r"[^A-Za-z]", " ", str(text))
    
     #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)

    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    # Remove punctuation from text
    text = "".join([c for c in text if c not in punctuation])
    stopwords = nltk.corpus.stopwords.words('english')
    text = text.split()
    text = [w for w in text if not w in stopwords]
    text = " ".join(text)
        
    text = text.split()
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in text]
    text = " ".join(lemmatized_words)
    text=text.lower()
    
    return text

# %%
df['cleaned_review'] = df['reviews'].apply(lambda x: text_cleaning(x))
df = df[df['cleaned_review'].map(len) > 0]

# %%
df
# Out:
#     index                                            reviews  \
# 0       0  \nIn all big cities there are self-contained g...
# 1       1  Books like this, that I’ve read so long ago in...
# 2       3  The best novel I've read since joining Goodrea...
# 3       5  Oh, Mr. Maugham, there are moments when I love...
# 4       6  In 1919 war hero Larry (Laurence) Darrell retu...
# 5       7  Tracing the intimate lives of representative B...
# 6       8  This has to be the most endearing and accessib...
# 7       9  A Timeless, stirring drama, scaling the height...
# 8      10  In Asian countries, the custom of “home leavin...
# 9      11  It took me a long time to read this book, this...
# 10     12  “Its a toss-up when you decide to leave the be...
# 11     14  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 12     15  I didn't love it as much as I expected. The pr...
# 13     16  "One of Maugham's three major novels ..." TIME...
# 14     17  I am considering starting a project to find ou...
# 15     18  Self-sacrifice, a most "overwhelming" human "p...
# 16     19  I love this book. I absolutely adore it.Larry ...
# 17     20  Back in the dark days of the mid-’80s, I read ...
# 18     24  110th book of 2021.Our guests the other day we...
# 19     27  Chatty, erudite, engrossing and thoroughly ent...
# 20     28  This is a perspicacious study of characters wh...
# 21     29  “'What’s the good of knowledge if you’re not g...
#
#                                        cleaned_review
# 0   in big city self contained group exist without...
# 1   books like i read long ago past come back even...
# 2   the best novel i read since joining goodreads ...
# 3   oh mr maugham moment i love much i could burst...
# 4   in war hero larry darrell return hometown chic...
# 5   tracing intimate life representative british a...
# 6   this endearing accessible maugham book with ri...
# 7   a timeless stirring drama scaling height ecsta...
# 8   in asian country custom home leaving common us...
# 9   it took long time read book beautiful book exc...
# 10  its toss decide leave beaten track many called...
# 11  rating fivethe publisher says intimate acquain...
# 12  i love much i expected the premise eastern phi...
# 13  one maugham three major novel time that high p...
# 14  i considering starting project find book infin...
# 15  self sacrifice overwhelming human passion this...
# 16  i love book i absolutely adore larry returned ...
# 17  back dark day mid i read somewhere bill murray...
# 18  th book our guest day english family friend li...
# 19  chatty erudite engrossing thoroughly entertain...
# 20  this perspicacious study character whose fate ...
# 21  what good knowledge going anything perhaps per...

# %% [markdown]
# ##### Testing the reviews data for emotions using model

# %%
test_tfidf = tfidf_vectorizer.transform(df['cleaned_review'])

ytest_pred=test_model_lr.predict(test_tfidf)

ytest_pred_cw=test_model_lr_cw.predict(test_tfidf)

# %%
df['predicted_label']=ytest_pred

df['predicted_label_cw']=ytest_pred_cw

# %%
df['predicted_emotion'] = df['predicted_label'].map(dic_emotions['emotion'])
df['predicted_emotion_cw'] = df['predicted_label_cw'].map(dic_emotions['emotion'])

# %%
df
# Out:
#     index                                            reviews  \
# 0       0  \nIn all big cities there are self-contained g...
# 1       1  Books like this, that I’ve read so long ago in...
# 2       3  The best novel I've read since joining Goodrea...
# 3       5  Oh, Mr. Maugham, there are moments when I love...
# 4       6  In 1919 war hero Larry (Laurence) Darrell retu...
# 5       7  Tracing the intimate lives of representative B...
# 6       8  This has to be the most endearing and accessib...
# 7       9  A Timeless, stirring drama, scaling the height...
# 8      10  In Asian countries, the custom of “home leavin...
# 9      11  It took me a long time to read this book, this...
# 10     12  “Its a toss-up when you decide to leave the be...
# 11     14  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 12     15  I didn't love it as much as I expected. The pr...
# 13     16  "One of Maugham's three major novels ..." TIME...
# 14     17  I am considering starting a project to find ou...
# 15     18  Self-sacrifice, a most "overwhelming" human "p...
# 16     19  I love this book. I absolutely adore it.Larry ...
# 17     20  Back in the dark days of the mid-’80s, I read ...
# 18     24  110th book of 2021.Our guests the other day we...
# 19     27  Chatty, erudite, engrossing and thoroughly ent...
# 20     28  This is a perspicacious study of characters wh...
# 21     29  “'What’s the good of knowledge if you’re not g...
#
#                                        cleaned_review  predicted_label  \
# 0   in big city self contained group exist without...                6
# 1   books like i read long ago past come back even...                6
# 2   the best novel i read since joining goodreads ...                6
# 3   oh mr maugham moment i love much i could burst...                6
# 4   in war hero larry darrell return hometown chic...                6
# 5   tracing intimate life representative british a...                6
# 6   this endearing accessible maugham book with ri...                6
# 7   a timeless stirring drama scaling height ecsta...                6
# 8   in asian country custom home leaving common us...                6
# 9   it took long time read book beautiful book exc...                6
# 10  its toss decide leave beaten track many called...                6
# 11  rating fivethe publisher says intimate acquain...                6
# 12  i love much i expected the premise eastern phi...                6
# 13  one maugham three major novel time that high p...                6
# 14  i considering starting project find book infin...                6
# 15  self sacrifice overwhelming human passion this...                6
# 16  i love book i absolutely adore larry returned ...                6
# 17  back dark day mid i read somewhere bill murray...                6
# 18  th book our guest day english family friend li...                6
# 19  chatty erudite engrossing thoroughly entertain...                6
# 20  this perspicacious study character whose fate ...                6
# 21  what good knowledge going anything perhaps per...                6
#
#     predicted_label_cw predicted_emotion predicted_emotion_cw
# 0                    6           neutral              neutral
# 1                    6           neutral              neutral
# 2                    6           neutral              neutral
# 3                    6           neutral              neutral
# 4                    6           neutral              neutral
# 5                    6           neutral              neutral
# 6                    6           neutral              neutral
# 7                    6           neutral              neutral
# 8                    5           neutral             surprise
# 9                    6           neutral              neutral
# 10                   6           neutral              neutral
# 11                   6           neutral              neutral
# 12                   6           neutral              neutral
# 13                   6           neutral              neutral
# 14                   6           neutral              neutral
# 15                   6           neutral              neutral
# 16                   6           neutral              neutral
# 17                   6           neutral              neutral
# 18                   6           neutral              neutral
# 19                   6           neutral              neutral
# 20                   6           neutral              neutral
# 21                   6           neutral              neutral

# %%
df['reviews'][0]
# Out:
# 'I read this every year at Christmas, and I always will do. Simply because of the atmosphere it evokes. This story is Christmas as far as I’m concerned. It wouldn’t be the same without it. It is perfectly festive and is also appropriately didactic. It is an allegory for what happens to those that are unnecessarily bitter and twisted, refusing to take part in a joyful occasion. It is a glimpse at what could happen to someone who rejects their family upon trivial grounds, and let’s themselves be set apart. It is also a suggestion that one shouldn’t be so concerned with money. Money isn’t everything; it certainly didn’t buy ol’ Scrooge happiness. But, Christmas did and will do so again.  ___________________________________You can connect with me on social media via My Linktree.__________________________________'

# %%
df['cleaned_review'][7]
# Out:
# 'yet another read as amazing ever one dickens best i think re read still favorite christmas story charles dickens never cease make smile feel multitude emotion first read wonderful absolutely wonderful i know taken long read story i also know taken long read anything charles dickens it surpassed expectation ironically great the concept idea behind story brilliant it surprised cleverness wit even though i went knowing story well i fell love dickens storytelling especially would address reader make narrative voice known his commentary victorian life social criticism known key aspect book i attest fact i loved described different holiday scene made vivid life magic the supernatural element involving spirit pure genius overall i get chapter people call short story included many important element including greatest character development literature this story blessing right hand tiny tim ebenezer scrooge'

# %%
df['reviews'][19]
# Out:
# "im usually not a seasonal reader, but this year i tried to make an effort to read a couple of holiday themed books and im so glad i saved this for last!i grew up very familiar with the story of ‘a christmas carol’ via multiple adaptations (shoutout to the flintstones version from my childhood!), but i cant believe i never read the actual book itself. dickens is such a well known author, so its difficult to not critique this as i normally would with a book. but i think the message of this story is so important and should be the focus of this review. i personally know how easy it is to get caught up in the hustle and bustle and materialism and stress that can surround the holiday season. we fixate so much on sales and good deals and buying things to make us happy, that we can forget a loving word or spending quality time with those we care about are really what should be a priority. we should remember that kindness is the best gift we can give. so let us follow scrooges (eventual) example, when he says ‘i will honour christmas in my heart, and try to keep it all the year,' and allow the christmas spirit be something we not only feel this time of year, but always. happy holidays and best wishes to all my fellow bookworms. <3↠ 4 stars"
