# %%
from bs4 import BeautifulSoup
import requests  
import numpy as np
import pandas as pd
from langdetect import detect
import re
import pickle
import torch
from string import punctuation 
import nltk
import nltk.data
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords

# %%
#importing libraries for models and nlp tasks
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

# %%
import datasets
from datasets import load_dataset
from datasets import load_metric

from sklearn.model_selection import train_test_split


from transformers import AutoTokenizer
from transformers import TrainingArguments
from transformers import Trainer


from transformers import AutoModelForSequenceClassification

# %%
tfidf_vectorizer=pickle.load(open('../tfidfvectors/tfidf_vect_clean.pkl','rb'))

# %%
test_model_lr_imb=pickle.load(open('../models/lr_mn_clean.pkl','rb'))
test_model_lr_cw=pickle.load(open('../models/lr_mn_clean_cw.pkl','rb'))

# %%
emotion = pd.read_csv('../labels_prediction/emotions.csv')
dic_emotions=emotion.to_dict('series')

print(dic_emotions['emotion'])
# Out:
# 0     sadness
# 1         joy
# 2        love
# 3       anger
# 4        fear
# 5    surprise
# Name: emotion, dtype: object

# %% [markdown]
# #### Webscraping goodreads website for getting reviews of a book
# ##### To get the link for the required book

# %%
data = {'q': "The Razor's Edge"}
book_url = "https://www.goodreads.com/search"
req = requests.get(book_url, params=data)

book_soup = BeautifulSoup(req.text, 'html.parser')

titles=book_soup.find_all('a', class_ = 'bookTitle')
title=[]
link=[]
for bookname in titles:
    title.append(bookname.get_text())
    link.append(bookname['href'])

# %% [markdown]
# ##### From all the links first link is the most closest search

# %%
rev="http://goodreads.com"+link[0]
rev_url = requests.get(rev)
rev_soup=BeautifulSoup(rev_url.content, 'html.parser')

# %% [markdown]
# ##### Getting reviews from the web page of the book

# %%
rev_list=[]
for x in rev_soup.find_all("section", {"class": "ReviewText"}):
    rev_list.append(x.text)

# %%
df=pd.DataFrame(rev_list, columns=['reviews'])
df
# Out:
#                                               reviews
# 0   \nIn all big cities there are self-contained g...
# 1   Books like this, that I’ve read so long ago in...
# 2   (Book 570 From 1001 Books) - The Razor’s Edge ...
# 3   The best novel I've read since joining Goodrea...
# 4   ASPRO IL CAMMINO VERSO LA SALVEZZAIl primo fil...
# 5   Oh, Mr. Maugham, there are moments when I love...
# 6   In 1919 war hero Larry (Laurence) Darrell retu...
# 7   Tracing the intimate lives of representative B...
# 8   This has to be the most endearing and accessib...
# 9   A Timeless, stirring drama, scaling the height...
# 10  In Asian countries, the custom of “home leavin...
# 11  It took me a long time to read this book, this...
# 12  “Its a toss-up when you decide to leave the be...
# 13  دلم میخواد مثل لری تو یه خونه کوچیک زندگی کنم،...
# 14  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 15  I didn't love it as much as I expected. The pr...
# 16  "One of Maugham's three major novels ..." TIME...
# 17  I am considering starting a project to find ou...
# 18  Self-sacrifice, a most "overwhelming" human "p...
# 19  I love this book. I absolutely adore it.Larry ...
# 20  Back in the dark days of the mid-’80s, I read ...
# 21  کی می‌تونه لاری رو دوست نداشته باشه و حسرت سبک...
# 22  «Η κόψη του ξυραφιού», συνολικά, είναι μια βαθ...
# 23  داشتم فکر می کردم که شخصیت یک نفر چقدر باید تا...
# 24  110th book of 2021.Our guests the other day we...
# 25  1.5بسیار ناکافی و کاملا سطحینویسنده محترممون، ...
# 26  Chatty, erudite, engrossing and thoroughly ent...
# 27  در کتاب لبه تیغ نویسنده آقای سامرست موام به جس...
# 28  This is a perspicacious study of characters wh...
# 29  “'What’s the good of knowledge if you’re not g...

# %% [markdown]
# ##### From all the languages in the reviews, selecting the english language reviews

# %%
def detect_en(text):
    try:
        return detect(text) == 'en'
    except:
        return False

# %%
df = df[df['reviews'].apply(detect_en)]
df=df.reset_index()
df
# Out:
#     index                                            reviews
# 0       0  \nIn all big cities there are self-contained g...
# 1       1  Books like this, that I’ve read so long ago in...
# 2       3  The best novel I've read since joining Goodrea...
# 3       5  Oh, Mr. Maugham, there are moments when I love...
# 4       6  In 1919 war hero Larry (Laurence) Darrell retu...
# 5       7  Tracing the intimate lives of representative B...
# 6       8  This has to be the most endearing and accessib...
# 7       9  A Timeless, stirring drama, scaling the height...
# 8      10  In Asian countries, the custom of “home leavin...
# 9      11  It took me a long time to read this book, this...
# 10     12  “Its a toss-up when you decide to leave the be...
# 11     14  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 12     15  I didn't love it as much as I expected. The pr...
# 13     16  "One of Maugham's three major novels ..." TIME...
# 14     17  I am considering starting a project to find ou...
# 15     18  Self-sacrifice, a most "overwhelming" human "p...
# 16     19  I love this book. I absolutely adore it.Larry ...
# 17     20  Back in the dark days of the mid-’80s, I read ...
# 18     24  110th book of 2021.Our guests the other day we...
# 19     26  Chatty, erudite, engrossing and thoroughly ent...
# 20     28  This is a perspicacious study of characters wh...
# 21     29  “'What’s the good of knowledge if you’re not g...

# %%
dataset=df.copy()

# %% [markdown]
# ##### Cleaning the text

# %%
def text_cleaning(text):
   
    text=re.sub("\(.*?\)","",text)

    text = re.sub(r"[^A-Za-z]", " ", str(text))
    
     #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)

    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    # Remove punctuation from text
    text = "".join([c for c in text if c not in punctuation])
    stopwords = nltk.corpus.stopwords.words('english')
    text = text.split()
    text = [w for w in text if not w in stopwords]
    text = " ".join(text)
        
    text = text.split()
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in text]
    text = " ".join(lemmatized_words)
    text=text.lower()
    
    return text

# %%
df['cleaned_review'] = df['reviews'].apply(lambda x: text_cleaning(x))
df = df[df['cleaned_review'].map(len) > 0]

# %%
df
# Out:
#     index                                            reviews  \
# 0       0  \nIn all big cities there are self-contained g...
# 1       1  Books like this, that I’ve read so long ago in...
# 2       3  The best novel I've read since joining Goodrea...
# 3       5  Oh, Mr. Maugham, there are moments when I love...
# 4       6  In 1919 war hero Larry (Laurence) Darrell retu...
# 5       7  Tracing the intimate lives of representative B...
# 6       8  This has to be the most endearing and accessib...
# 7       9  A Timeless, stirring drama, scaling the height...
# 8      10  In Asian countries, the custom of “home leavin...
# 9      11  It took me a long time to read this book, this...
# 10     12  “Its a toss-up when you decide to leave the be...
# 11     14  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 12     15  I didn't love it as much as I expected. The pr...
# 13     16  "One of Maugham's three major novels ..." TIME...
# 14     17  I am considering starting a project to find ou...
# 15     18  Self-sacrifice, a most "overwhelming" human "p...
# 16     19  I love this book. I absolutely adore it.Larry ...
# 17     20  Back in the dark days of the mid-’80s, I read ...
# 18     24  110th book of 2021.Our guests the other day we...
# 19     26  Chatty, erudite, engrossing and thoroughly ent...
# 20     28  This is a perspicacious study of characters wh...
# 21     29  “'What’s the good of knowledge if you’re not g...
#
#                                        cleaned_review
# 0   in big city self contained group exist without...
# 1   books like i read long ago past come back even...
# 2   the best novel i read since joining goodreads ...
# 3   oh mr maugham moment i love much i could burst...
# 4   in war hero larry darrell return hometown chic...
# 5   tracing intimate life representative british a...
# 6   this endearing accessible maugham book with ri...
# 7   a timeless stirring drama scaling height ecsta...
# 8   in asian country custom home leaving common us...
# 9   it took long time read book beautiful book exc...
# 10  its toss decide leave beaten track many called...
# 11  rating fivethe publisher says intimate acquain...
# 12  i love much i expected the premise eastern phi...
# 13  one maugham three major novel time that high p...
# 14  i considering starting project find book infin...
# 15  self sacrifice overwhelming human passion this...
# 16  i love book i absolutely adore larry returned ...
# 17  back dark day mid i read somewhere bill murray...
# 18  th book our guest day english family friend li...
# 19  chatty erudite engrossing thoroughly entertain...
# 20  this perspicacious study character whose fate ...
# 21  what good knowledge going anything perhaps per...

# %% [markdown]
# ##### Testing the reviews data for emotions using model

# %%
test_tfidf = tfidf_vectorizer.transform(df['cleaned_review'])

ytest_pred_imb=test_model_lr_imb.predict(test_tfidf)
ytest_pred_cw=test_model_lr_cw.predict(test_tfidf)

# %%
df['predicted_label_imb']=ytest_pred_imb
df['predicted_label_cw']=ytest_pred_cw

# %%
df['predicted_emotion_imb'] = df['predicted_label_imb'].map(dic_emotions['emotion'])
df['predicted_emotion_cw'] = df['predicted_label_cw'].map(dic_emotions['emotion'])

# %%
percentage_emotions=(df['predicted_emotion_cw'].value_counts(normalize=True)*100).to_dict()
type(percentage_emotions)
# Out:
# dict

# %%
percentage_emotions = {k: int(round(v, 0)) for k, v in percentage_emotions.items()}
percentage_emotions
# Out:
# {'joy': 45, 'surprise': 23, 'sadness': 9, 'love': 9, 'anger': 9, 'fear': 5}

# %% [markdown]
# BERT fine tuned model

# %%
bert_model=AutoModelForSequenceClassification.from_pretrained('../models/bert_finetuned_model2')
trainer=Trainer(bert_model)

tokenizer=AutoTokenizer.from_pretrained('bert-base-cased')
tokenizer
# Out:
# loading configuration file config.json from cache at /Users/phanisingaraju/.cache/huggingface/hub/models--bert-base-cased/snapshots/5532cc56f74641d4bb33641f5c76a55d11f846e0/config.json
# Model config BertConfig {
#   "_name_or_path": "bert-base-cased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.25.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# loading file vocab.txt from cache at /Users/phanisingaraju/.cache/huggingface/hub/models--bert-base-cased/snapshots/5532cc56f74641d4bb33641f5c76a55d11f846e0/vocab.txt
# loading file tokenizer.json from cache at /Users/phanisingaraju/.cache/huggingface/hub/models--bert-base-cased/snapshots/5532cc56f74641d4bb33641f5c76a55d11f846e0/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /Users/phanisingaraju/.cache/huggingface/hub/models--bert-base-cased/snapshots/5532cc56f74641d4bb33641f5c76a55d11f846e0/tokenizer_config.json
# loading configuration file config.json from cache at /Users/phanisingaraju/.cache/huggingface/hub/models--bert-base-cased/snapshots/5532cc56f74641d4bb33641f5c76a55d11f846e0/config.json
# Model config BertConfig {
#   "_name_or_path": "bert-base-cased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.25.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
# PreTrainedTokenizerFast(name_or_path='bert-base-cased', vocab_size=28996, model_max_len=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
test_dataset = datasets.Dataset.from_dict(dataset)

# %%
my_dataset_dict = datasets.DatasetDict({"test":test_dataset})

# %%
my_dataset_dict
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['index', 'reviews'],
#         num_rows: 22
#     })
# })

# %%
def tokenize_data(example):
    return tokenizer(example['reviews'],truncation=True, padding='max_length')

my_dataset_dict = my_dataset_dict.map(tokenize_data, batched=True)
#my_dataset_dict = my_dataset_dict.map(remove_columns='index')
my_dataset_dict
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
# DatasetDict({
#     test: Dataset({
#         features: ['index', 'reviews', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 22
#     })
# })

# %%
predicted_results=trainer.predict(my_dataset_dict['test'])
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: reviews, index. If reviews, index are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 22
#   Batch size = 8

# %%
predicted_results.predictions.shape
# Out:
# (22, 6)

# %%
predicted_labels = predicted_results.predictions.argmax(-1) # Get the highest probability prediction
predicted_labels = predicted_labels.flatten().tolist() 
predicted_labels
# Out:
# [5, 3, 1, 1, 1, 1, 1, 0, 1, 2, 1, 1, 3, 0, 1, 1, 1, 1, 3, 1, 0, 5]

# %%
df['predicted_label_bert']=predicted_labels

# %%
df['predicted_emotion_bert'] = df['predicted_label_bert'].map(dic_emotions['emotion'])

# %%
df
# Out:
#     index                                            reviews  \
# 0       0  \nIn all big cities there are self-contained g...
# 1       1  Books like this, that I’ve read so long ago in...
# 2       3  The best novel I've read since joining Goodrea...
# 3       5  Oh, Mr. Maugham, there are moments when I love...
# 4       6  In 1919 war hero Larry (Laurence) Darrell retu...
# 5       7  Tracing the intimate lives of representative B...
# 6       8  This has to be the most endearing and accessib...
# 7       9  A Timeless, stirring drama, scaling the height...
# 8      10  In Asian countries, the custom of “home leavin...
# 9      11  It took me a long time to read this book, this...
# 10     12  “Its a toss-up when you decide to leave the be...
# 11     14  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 12     15  I didn't love it as much as I expected. The pr...
# 13     16  "One of Maugham's three major novels ..." TIME...
# 14     17  I am considering starting a project to find ou...
# 15     18  Self-sacrifice, a most "overwhelming" human "p...
# 16     19  I love this book. I absolutely adore it.Larry ...
# 17     20  Back in the dark days of the mid-’80s, I read ...
# 18     24  110th book of 2021.Our guests the other day we...
# 19     26  Chatty, erudite, engrossing and thoroughly ent...
# 20     28  This is a perspicacious study of characters wh...
# 21     29  “'What’s the good of knowledge if you’re not g...
#
#                                        cleaned_review  predicted_label_imb  \
# 0   in big city self contained group exist without...                    1
# 1   books like i read long ago past come back even...                    1
# 2   the best novel i read since joining goodreads ...                    1
# 3   oh mr maugham moment i love much i could burst...                    4
# 4   in war hero larry darrell return hometown chic...                    1
# 5   tracing intimate life representative british a...                    1
# 6   this endearing accessible maugham book with ri...                    1
# 7   a timeless stirring drama scaling height ecsta...                    0
# 8   in asian country custom home leaving common us...                    1
# 9   it took long time read book beautiful book exc...                    1
# 10  its toss decide leave beaten track many called...                    1
# 11  rating fivethe publisher says intimate acquain...                    1
# 12  i love much i expected the premise eastern phi...                    1
# 13  one maugham three major novel time that high p...                    0
# 14  i considering starting project find book infin...                    1
# 15  self sacrifice overwhelming human passion this...                    1
# 16  i love book i absolutely adore larry returned ...                    1
# 17  back dark day mid i read somewhere bill murray...                    5
# 18  th book our guest day english family friend li...                    1
# 19  chatty erudite engrossing thoroughly entertain...                    1
# 20  this perspicacious study character whose fate ...                    0
# 21  what good knowledge going anything perhaps per...                    1
#
#     predicted_label_cw predicted_emotion_imb predicted_emotion_cw  \
# 0                    5                   joy             surprise
# 1                    5                   joy             surprise
# 2                    1                   joy                  joy
# 3                    4                  fear                 fear
# 4                    1                   joy                  joy
# 5                    1                   joy                  joy
# 6                    1                   joy                  joy
# 7                    0               sadness              sadness
# 8                    5                   joy             surprise
# 9                    2                   joy                 love
# 10                   1                   joy                  joy
# 11                   1                   joy                  joy
# 12                   3                   joy                anger
# 13                   2               sadness                 love
# 14                   5                   joy             surprise
# 15                   1                   joy                  joy
# 16                   1                   joy                  joy
# 17                   5              surprise             surprise
# 18                   3                   joy                anger
# 19                   1                   joy                  joy
# 20                   0               sadness              sadness
# 21                   1                   joy                  joy
#
#     predicted_label_bert predicted_emotion_bert
# 0                      5               surprise
# 1                      3                  anger
# 2                      1                    joy
# 3                      1                    joy
# 4                      1                    joy
# 5                      1                    joy
# 6                      1                    joy
# 7                      0                sadness
# 8                      1                    joy
# 9                      2                   love
# 10                     1                    joy
# 11                     1                    joy
# 12                     3                  anger
# 13                     0                sadness
# 14                     1                    joy
# 15                     1                    joy
# 16                     1                    joy
# 17                     1                    joy
# 18                     3                  anger
# 19                     1                    joy
# 20                     0                sadness
# 21                     5               surprise

# %%
df.columns
# Out:
# Index(['index', 'reviews', 'cleaned_review', 'predicted_label_imb',
#        'predicted_label_cw', 'predicted_emotion_imb', 'predicted_emotion_cw',
#        'predicted_label_bert', 'predicted_emotion_bert'],
#       dtype='object')

# %% [markdown]
# Comparing the predictions from all the three models

# %%
compare=df[['reviews','cleaned_review','predicted_emotion_imb', 'predicted_emotion_cw','predicted_emotion_bert']]
compare
# Out:
#                                               reviews  \
# 0   \nIn all big cities there are self-contained g...
# 1   Books like this, that I’ve read so long ago in...
# 2   The best novel I've read since joining Goodrea...
# 3   Oh, Mr. Maugham, there are moments when I love...
# 4   In 1919 war hero Larry (Laurence) Darrell retu...
# 5   Tracing the intimate lives of representative B...
# 6   This has to be the most endearing and accessib...
# 7   A Timeless, stirring drama, scaling the height...
# 8   In Asian countries, the custom of “home leavin...
# 9   It took me a long time to read this book, this...
# 10  “Its a toss-up when you decide to leave the be...
# 11  Rating: 4.25* of fiveThe Publisher Says: Intim...
# 12  I didn't love it as much as I expected. The pr...
# 13  "One of Maugham's three major novels ..." TIME...
# 14  I am considering starting a project to find ou...
# 15  Self-sacrifice, a most "overwhelming" human "p...
# 16  I love this book. I absolutely adore it.Larry ...
# 17  Back in the dark days of the mid-’80s, I read ...
# 18  110th book of 2021.Our guests the other day we...
# 19  Chatty, erudite, engrossing and thoroughly ent...
# 20  This is a perspicacious study of characters wh...
# 21  “'What’s the good of knowledge if you’re not g...
#
#                                        cleaned_review predicted_emotion_imb  \
# 0   in big city self contained group exist without...                   joy
# 1   books like i read long ago past come back even...                   joy
# 2   the best novel i read since joining goodreads ...                   joy
# 3   oh mr maugham moment i love much i could burst...                  fear
# 4   in war hero larry darrell return hometown chic...                   joy
# 5   tracing intimate life representative british a...                   joy
# 6   this endearing accessible maugham book with ri...                   joy
# 7   a timeless stirring drama scaling height ecsta...               sadness
# 8   in asian country custom home leaving common us...                   joy
# 9   it took long time read book beautiful book exc...                   joy
# 10  its toss decide leave beaten track many called...                   joy
# 11  rating fivethe publisher says intimate acquain...                   joy
# 12  i love much i expected the premise eastern phi...                   joy
# 13  one maugham three major novel time that high p...               sadness
# 14  i considering starting project find book infin...                   joy
# 15  self sacrifice overwhelming human passion this...                   joy
# 16  i love book i absolutely adore larry returned ...                   joy
# 17  back dark day mid i read somewhere bill murray...              surprise
# 18  th book our guest day english family friend li...                   joy
# 19  chatty erudite engrossing thoroughly entertain...                   joy
# 20  this perspicacious study character whose fate ...               sadness
# 21  what good knowledge going anything perhaps per...                   joy
#
#    predicted_emotion_cw predicted_emotion_bert
# 0              surprise               surprise
# 1              surprise                  anger
# 2                   joy                    joy
# 3                  fear                    joy
# 4                   joy                    joy
# 5                   joy                    joy
# 6                   joy                    joy
# 7               sadness                sadness
# 8              surprise                    joy
# 9                  love                   love
# 10                  joy                    joy
# 11                  joy                    joy
# 12                anger                  anger
# 13                 love                sadness
# 14             surprise                    joy
# 15                  joy                    joy
# 16                  joy                    joy
# 17             surprise                    joy
# 18                anger                  anger
# 19                  joy                    joy
# 20              sadness                sadness
# 21                  joy               surprise

# %%
df.groupby(['predicted_emotion_imb'])['predicted_emotion_imb'].count()
# Out:
# predicted_emotion_imb
# fear         1
# joy         17
# sadness      3
# surprise     1
# Name: predicted_emotion_imb, dtype: int64

# %%
df.groupby(['predicted_emotion_cw'])['predicted_emotion_cw'].count()
# Out:
# predicted_emotion_cw
# anger        2
# fear         1
# joy         10
# love         2
# sadness      2
# surprise     5
# Name: predicted_emotion_cw, dtype: int64

# %%
df.groupby(['predicted_emotion_bert'])['predicted_emotion_bert'].count()
# Out:
# predicted_emotion_bert
# anger        3
# joy         13
# love         1
# sadness      3
# surprise     2
# Name: predicted_emotion_bert, dtype: int64

# %%
df['reviews'][0]
# Out:
# "\nIn all big cities there are self-contained groups that exist without intercommunication, small worlds within a greater world that lead their lives, their members dependent upon one another for companionship, as though they inhabited islands separated from each other by an unnavigable strait. Of no city, in my experience, is this more true than of Paris.\n4 ½ stars. I liked this book a lot. Much more than Maugham's Of Human Bondage, but not quite as much as The Painted Veil. The first person minor perspective works really well here. Maugham inserts himself into the story, but mostly exists as an observer and messenger, retelling the tales passed to him by Elliott, Larry, Isabel and others. I think this is one of the most interesting narrative structures-- we are still a