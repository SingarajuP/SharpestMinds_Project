# %%
import pandas as pd
import numpy as np
import re
from string import punctuation

# %%
df=pd.read_csv("movies_meta.csv")

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 3  False                                                NaN   3600000
# 4  False                                                NaN  29500000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                             homepage    id    imdb_id  \
# 0               http://toystory.disney.com/toy-story   862  tt0114709
# 1                                                NaN  8844  tt0113497
# ...

# %%
df.shape
# Out:
# (4690, 24)

# %%
df_sub=pd.read_csv("movies_subtitles.csv")

# %%
df_sub.shape
# Out:
# (10358496, 4)

# %%
df_sub.head()
# Out:
#    start_time  end_time                                               text  \
# 0      58.559    61.602  BOY: All right, everyone!\nThis... is a stick-up!
# 1      61.687    63.354                                Don't anybody move!
# 2      64.398    66.482                              Now, empty that safe!
# 3      68.318    71.612       Ooh-hoo-hoo!\nMoney, money, money! (KISSING)
# 4      71.697    74.031           Stop it! Stop it,\nyou mean, old potato!
#
#      imdb_id
# 0  tt0114709
# 1  tt0114709
# 2  tt0114709
# 3  tt0114709
# 4  tt0114709

# %%
df_sub.groupby(['imdb_id']).count()
# Out:
#            start_time  end_time  text
# imdb_id
# tt0002130        1049      1049  1049
# tt0005044        1338      1338  1338
# tt0005059        3471      3471  3471
# tt0005060        1457      1457  1457
# tt0007338        2834      2834  2772
# ...               ...       ...   ...
# tt6176078        3771      3771  3771
# tt6210808        2476      2476  2476
# tt6212346        1515      1515  1515
# tt6582384         246       246   246
# tt6739646        3372      3372  3372
#
# [4666 rows x 3 columns]

# %%
df_sub['text'][25]
# Out:
# "♪ You've got a friend in me"

# %%
imdb=df.loc[df['title'] == 'Toy Story']['imdb_id']
imdb
# Out:
# 0    tt0114709
# Name: imdb_id, dtype: object

# %%
imdb[0]
# Out:
# 'tt0114709'

# %%
df_t=df_sub.loc[df_sub['imdb_id']==imdb[0]]

# %%
df_t
# Out:
#         start_time  end_time  \
# 0           58.559    61.602
# 1           61.687    63.354
# 2           64.398    66.482
# 3           68.318    71.612
# 4           71.697    74.031
# ...            ...       ...
# 680741    4722.509  4725.595
# 680742    4727.139  4731.935
# 680743    4732.019  4735.980
# 680744    4736.065  4738.650
# 680745    4740.319  4840.877
#
#                                                      text    imdb_id
# 0       BOY: All right, everyone!\nThis... is a stick-up!  tt0114709
# 1                                     Don't anybody move!  tt0114709
# 2                                   Now, empty that safe!  tt0114709
# 3            Ooh-hoo-hoo!\nMoney, money, money! (KISSING)  tt0114709
# 4                Stop it! Stop it,\nyou mean, old potato!  tt0114709
# ...                                                   ...        ...
# 680741                    ♪ Our friendship will never die  tt0114709
# ...

# %%
import nltk
import nltk.data
from string import punctuation 
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords

# %%
def text_cleaning(text):
    #print("I am going to clean the text:",text)
    # Clean the text, with the option to remove stop_words and to lemmatize word
    # Clean the text
    text = re.sub(r"[^A-Za-z]", " ", text)
    #text = re.sub(r"\'s", " ", text)
    #text = re.sub(r"http\S+", " link ", text)
    #text = re.sub(r"\b\d+(?:\.\d+)?\s+", "", text)  # remove numbers
    
    # Remove punctuation from text
    text = "".join([c for c in text if c not in punctuation])
    stopwords = nltk.corpus.stopwords.words('english')
    text = text.split()
    text = [w for w in text if not w in stopwords]
    text = " ".join(text)
        
    text = text.split()
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in text]
    text = " ".join(lemmatized_words)
    text=text.lower()
      #print("I am returning the cleaned text:",text)      
    # Return a list of words
    return text

# %%
df_t['cleaned_text'] = df_t['text'].apply(lambda x: text_cleaning(x))
# Out:
# /var/folders/th/qgn0zvb111n4qgsdq1z81tj00000gn/T/ipykernel_16591/696979002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['cleaned_text'] = df_t['text'].apply(lambda x: text_cleaning(x))

# %%
df_t
# Out:
#         start_time  end_time  \
# 0           58.559    61.602
# 1           61.687    63.354
# 2           64.398    66.482
# 3           68.318    71.612
# 4           71.697    74.031
# ...            ...       ...
# 680741    4722.509  4725.595
# 680742    4727.139  4731.935
# 680743    4732.019  4735.980
# 680744    4736.065  4738.650
# 680745    4740.319  4840.877
#
#                                                      text    imdb_id  \
# 0       BOY: All right, everyone!\nThis... is a stick-up!  tt0114709
# 1                                     Don't anybody move!  tt0114709
# 2                                   Now, empty that safe!  tt0114709
# 3            Ooh-hoo-hoo!\nMoney, money, money! (KISSING)  tt0114709
# 4                Stop it! Stop it,\nyou mean, old potato!  tt0114709
# ...                                                   ...        ...
# 680741                    ♪ Our friendship will never die  tt0114709
# ...

# %%
df_t['cleaned_text'].to_csv("cleaned_text.csv", index=False, header=False)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
import pickle
import itertools
import os
import csv

# %%
#importing libraries for models and nlp tasks
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

#from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
#from sklearn.preprocessing import MultiLabelBinarizer
#from sklearn.preprocessing import StandardScaler
#from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
#from sklearn.multioutput import MultiOutputClassifier
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

# %%
working_directory=os.getcwd()
#path=working_directory+'/data/merged_training.pkl'
#path

# %%
working_directory
# Out:
# '/Users/phanisingaraju/SM/Datasets/movie_subtitle'

# %%
tfidf_vectorizer=pickle.load(open('/Users/phanisingaraju/SM/Datasets/emotion_analysis//models/tfidf_vect.pkl','rb'))

# %%
test_tfidf = tfidf_vectorizer.transform(df_t['cleaned_text'])

# %%
test_model_lr=pickle.load(open('/Users/phanisingaraju/SM/Datasets/emotion_analysis//models/LR_MN.pkl','rb'))
# Out:
# /Users/phanisingaraju/opt/anaconda3/envs/emotionanalysis_env/lib/python3.10/site-packages/sklearn/base.py:288: UserWarning: Trying to unpickle estimator LogisticRegression from version 1.0.2 when using version 1.2.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
ytest_pred=test_model_lr.predict(test_tfidf)
ytest_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
df_t['Predicted_label']=ytest_pred
# Out:
# /var/folders/th/qgn0zvb111n4qgsdq1z81tj00000gn/T/ipykernel_16591/1800287366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['Predicted_label']=ytest_pred

# %%
df_t
# Out:
#         start_time  end_time  \
# 0           58.559    61.602
# 1           61.687    63.354
# 2           64.398    66.482
# 3           68.318    71.612
# 4           71.697    74.031
# ...            ...       ...
# 680741    4722.509  4725.595
# 680742    4727.139  4731.935
# 680743    4732.019  4735.980
# 680744    4736.065  4738.650
# 680745    4740.319  4840.877
#
#                                                      text    imdb_id  \
# 0       BOY: All right, everyone!\nThis... is a stick-up!  tt0114709
# 1                                     Don't anybody move!  tt0114709
# 2                                   Now, empty that safe!  tt0114709
# 3            Ooh-hoo-hoo!\nMoney, money, money! (KISSING)  tt0114709
# 4                Stop it! Stop it,\nyou mean, old potato!  tt0114709
# ...                                                   ...        ...
# 680741                    ♪ Our friendship will never die  tt0114709
# ...

# %%
df_t['Predicted_label']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0
#          ..
# 680741    0
# 680742    1
# 680743    1
# 680744    1
# 680745    1
# Name: Predicted_label, Length: 4158, dtype: int64

# %%
emotion = pd.read_csv('/Users/phanisingaraju/SM/Datasets/emotion_analysis//models/emotions.csv')

# %%
dic_emotions=emotion.to_dict('series')

# %%
dic_emotions['Emotion']
# Out:
# {'Emotion': 0     sadness
#  1         joy
#  2        love
#  3       anger
#  4        fear
#  5    surprise
#  Name: Emotion, dtype: object}

# %%
df_t['Predicted_emotion'] = df_t['Predicted_label'].map(dic_emotions['Emotion'])
# Out:
# /var/folders/th/qgn0zvb111n4qgsdq1z81tj00000gn/T/ipykernel_16591/3838699278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['Predicted_emotion'] = df_t['Predicted_label'].map(dic_emotions['Emotion'])

# %%
df_t
# Out:
#         start_time  end_time  \
# 0           58.559    61.602
# 1           61.687    63.354
# 2           64.398    66.482
# 3           68.318    71.612
# 4           71.697    74.031
# ...            ...       ...
# 680741    4722.509  4725.595
# 680742    4727.139  4731.935
# 680743    4732.019  4735.980
# 680744    4736.065  4738.650
# 680745    4740.319  4840.877
#
#                                                      text    imdb_id  \
# 0       BOY: All right, everyone!\nThis... is a stick-up!  tt0114709
# 1                                     Don't anybody move!  tt0114709
# 2                                   Now, empty that safe!  tt0114709
# 3            Ooh-hoo-hoo!\nMoney, money, money! (KISSING)  tt0114709
# 4                Stop it! Stop it,\nyou mean, old potato!  tt0114709
# ...                                                   ...        ...
# 680741                    ♪ Our friendship will never die  tt0114709
# ...

# %%
df_t.groupby(['Predicted_emotion']).count()
# Out:
#                    start_time  end_time  text  imdb_id  cleaned_text  \
# Predicted_emotion
# anger                     135       135   135      135           135
# fear                       45        45    45       45            45
# joy                      3486      3486  3486     3486          3486
# love                        9         9     9        9             9
# sadness                   444       444   444      444           444
# surprise                   39        39    39       39            39
#
#                    Predicted_label
# Predicted_emotion
# anger                          135
# fear                            45
# joy                           3486
# love                             9
# sadness                        444
# surprise                        39
